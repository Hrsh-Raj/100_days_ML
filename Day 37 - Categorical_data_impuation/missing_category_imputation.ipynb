# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv('train.csv', usecols=['GarageQual','FireplaceQu','SalePrice'])
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot.bar()
plt.xlabel('Garage Qual')
plt.ylabel('Number or houses')
# Out:
# Text(0, 0.5, 'Number or houses')

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
df['GarageQual'].fillna('Missing', inplace=True)
# Out:
# C:\Users\hrsh.raj\AppData\Local\Temp\ipykernel_27804\4070582888.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna('Missing', inplace=True)

# %%
df['GarageQual'].value_counts()
# Out:
# GarageQual
# TA         1311
# Missing      81
# Fa           48
# Gd           14
# Ex            3
# Po            3
# Name: count, dtype: int64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns='SalePrice'), df['SalePrice'], test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1168, 2), (292, 2), (1168,), (292,))

# %%
imputer = SimpleImputer(strategy='constant', fill_value='Missing')

# %%
X_train_trf = imputer.fit_transform(X_train)
X_test_trf = imputer.transform(X_test)

# %%
imputer.statistics_
# Out:
# array(['Missing', 'Missing'], dtype=object)
